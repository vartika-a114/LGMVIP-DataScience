# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
# loading the images 
img = cv2.imread('jeff_bezos.jfif', 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F23186D0FD0>

# %%
# converting image into grayscale 
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2318614110>

# %%
# inverting an image 
img_invert = cv2.bitwise_not(img_gray)
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F2317CD5690>

# %%
# smoothing an image 
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F2317CD86D0>

# %%
# final pencil sketch 
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F2317D29890>
